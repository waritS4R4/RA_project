# %%
# check initialisation 
import MSc_stage2_cleaned as stage2
import Monitored_file as mf

stage2.initialise(mf.CURRENT_HOUR)

i = 0; # initialise i 
for i in range(5): #
    print(mf.CURRENT_HOUR)
    stage2.initialise(mf.CURRENT_HOUR)
    stage2.main() 
    stage2.iterate()

# after 21 hours, it runs into problems of the cut-off
# validate the 5 mins contorl action 
# stage2.initialise_plot(10)
stage2.plot_results(name="stage2_hourly_results.csv",hours=list(range(0,5)),plots="all")
# Out:
# 5
# this is 2nd stage for Co-optimisation
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i7-14700, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 28 logical processors, using up to 28 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 3170 rows, 1296 columns and 9529 nonzeros (Min)
# Model fingerprint: 0x354fb06d
# Model has 144 linear objective coefficients
# Model has 94 quadratic constraints
# Variable types: 1200 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [8e-04, 3e+02]
#   QMatrix range    [6e+02, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 3e+03]
#   RHS range        [2e-05, 6e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 2848 rows and 692 columns
# Presolve time: 0.01s
# Presolved: 1157 rows, 789 columns, 5280 nonzeros
# Presolved model has 186 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 743 continuous, 46 integer (46 binary)
# Found heuristic solution: objective 1.3114306
#
# Root relaxation: cutoff, 765 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         1.31143    1.31143  0.00%     -    0s
#
# Explored 1 nodes (765 simplex iterations) in 0.04 seconds (0.06 work units)
# Thread count was 28 (of 28 available processors)
#
# Solution count 1: 1.31143
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.311430553366e+00, best bound 1.311430553366e+00, gap 0.0000%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: 1.3114
#   Energy cost term: 1.3778
#   Heat penalty term: 5.2736
# current hour: 5
# next hour: 6
# 6
# this is 2nd stage for Co-optimisation
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i7-14700, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 28 logical processors, using up to 28 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 3170 rows, 1296 columns and 9529 nonzeros (Min)
# Model fingerprint: 0x144674c4
# Model has 144 linear objective coefficients
# Model has 94 quadratic constraints
# Variable types: 1200 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [8e-04, 3e+02]
#   QMatrix range    [6e+02, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 3e+03]
#   RHS range        [2e-05, 6e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 2848 rows and 704 columns
# Presolve time: 0.01s
# Presolved: 1157 rows, 777 columns, 5208 nonzeros
# Presolved model has 186 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 731 continuous, 46 integer (46 binary)
# Found heuristic solution: objective 1.0716234
#
# Root relaxation: interrupted, 802 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0         1.07162    1.07162  0.00%     -    0s
#
# Explored 1 nodes (802 simplex iterations) in 0.04 seconds (0.05 work units)
# Thread count was 28 (of 28 available processors)
#
# Solution count 1: 1.07162
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.071623438415e+00, best bound 1.071623251404e+00, gap 0.0000%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: 1.0716
#   Energy cost term: 0.1749
#   Heat penalty term: 0.1622
# current hour: 6
# next hour: 7
# 7
# this is 2nd stage for Co-optimisation
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i7-14700, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 28 logical processors, using up to 28 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 3170 rows, 1296 columns and 9529 nonzeros (Min)
# Model fingerprint: 0xcec34f4b
# Model has 144 linear objective coefficients
# Model has 94 quadratic constraints
# Variable types: 1200 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [8e-04, 3e+02]
#   QMatrix range    [6e+02, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 3e+03]
#   RHS range        [2e-05, 6e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 2848 rows and 716 columns
# Presolve time: 0.01s
# Presolved: 1157 rows, 765 columns, 5136 nonzeros
# Presolved model has 186 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 719 continuous, 46 integer (46 binary)
# Found heuristic solution: objective 0.6662159
#
# Root relaxation: interrupted, 692 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0         0.66622    0.66622  0.00%     -    0s
#
# Explored 1 nodes (692 simplex iterations) in 0.04 seconds (0.05 work units)
# Thread count was 28 (of 28 available processors)
#
# Solution count 1: 0.666216
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.662159205831e-01, best bound 6.662157095854e-01, gap 0.0000%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: 0.6662
#   Energy cost term: 0.0884
#   Heat penalty term: 0.1359
# current hour: 7
# next hour: 8
# 8
# this is 2nd stage for Co-optimisation
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i7-14700, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 28 logical processors, using up to 28 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 3170 rows, 1296 columns and 9529 nonzeros (Min)
# Model fingerprint: 0x3155feaa
# Model has 144 linear objective coefficients
# Model has 94 quadratic constraints
# Variable types: 1200 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [8e-04, 3e+02]
#   QMatrix range    [6e+02, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 3e+03]
#   RHS range        [2e-05, 6e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 2848 rows and 728 columns
# Presolve time: 0.01s
# Presolved: 1157 rows, 753 columns, 5064 nonzeros
# Presolved model has 186 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 707 continuous, 46 integer (46 binary)
# Found heuristic solution: objective 0.2750640
#
# Root relaxation: cutoff, 724 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         0.27506    0.27506  0.00%     -    0s
#
# Explored 1 nodes (724 simplex iterations) in 0.04 seconds (0.06 work units)
# Thread count was 28 (of 28 available processors)
#
# Solution count 1: 0.275064
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.750640382242e-01, best bound 2.750640382242e-01, gap 0.0000%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: 0.2751
#   Energy cost term: -0.0104
#   Heat penalty term: 0.1455
# current hour: 8
# next hour: 9
# 9
# this is 2nd stage for Co-optimisation
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i7-14700, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 28 logical processors, using up to 28 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 3170 rows, 1296 columns and 9529 nonzeros (Min)
# Model fingerprint: 0xd3de2adf
# Model has 144 linear objective coefficients
# Model has 94 quadratic constraints
# Variable types: 1200 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [8e-04, 3e+02]
#   QMatrix range    [6e+02, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 3e+03]
#   RHS range        [2e-05, 1e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 2848 rows and 739 columns
# Presolve time: 0.01s
# Presolved: 1157 rows, 742 columns, 5000 nonzeros
# Presolved model has 186 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 696 continuous, 46 integer (46 binary)
# Found heuristic solution: objective -0.0573750
#
# Root relaxation: objective -5.743102e-02, 629 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      -0.0574310   -0.05743  0.00%     -    0s
#
# Explored 1 nodes (629 simplex iterations) in 0.04 seconds (0.06 work units)
# Thread count was 28 (of 28 available processors)
#
# Solution count 2: -0.057431 -0.057375
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.743101881357e-02, best bound -5.743101881357e-02, gap 0.0000%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: -0.0574
#   Energy cost term: -0.0462
#   Heat penalty term: 0.0000
# current hour: 9
# next hour: 10
