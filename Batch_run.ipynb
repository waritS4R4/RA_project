# %%
# To create a day ahead schedule 
import MSc_stage1_cleaned as stage1
stage1.initialise()
# stage1.plot_step_response(stage1.A, stage1.B, stage1.C, stage1.D, stage1.Ts_hour)
# stage1.plot_step_response(stage1.A_5min, stage1.B_5min, stage1.C_5min, stage1.D_5min, stage1.Ts_5min)

stage1.main()
stage1.plot()

# %%
# check initialisation 
import MSc_stage2_cleaned as stage2
import Monitored_file as mf

#stage2.initialise(mf.CURRENT_HOUR)
i = 0; # initialise i 
for i in range(21): #
    print(mf.CURRENT_HOUR)
    stage2.initialise(mf.CURRENT_HOUR)
    stage2.main() 
    stage2.iterate()

# after 21 hours, it runs into problems of the cut-off
# validate the 5 mins control action 
# stage2.initialise_plot(10)
# Out:
# Objective type selected: Multi-objective
# 0
# Eigenvalues of the discrete system: [1.83670992e-40 1.49168444e-24 1.83670992e-40 1.49168444e-24]
# The discrete-time system (A_dis) is stable.
# The discrete-time system (A_5min) is stable.
# m:\RA_project\MSc_stage1_cleaned.py:287: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   times = pd.date_range('2022-01-01', '2022-12-31 23:00', freq='1H', tz=tz)     # Time range
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i7-14700, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 28 logical processors, using up to 28 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 967 rows, 1296 columns and 5500 nonzeros (Min)
# Model fingerprint: 0x2cdac328
# Model has 144 linear objective coefficients
# Model has 96 quadratic constraints
# Variable types: 1200 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+02]
#   QMatrix range    [1e+03, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 3e+03]
#   RHS range        [5e-02, 4e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 538 rows and 493 columns
# Presolve time: 0.06s
# Presolved: 988 rows, 896 columns, 5450 nonzeros
# Presolved model has 140 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 849 continuous, 47 integer (47 binary)
# Found heuristic solution: objective 1.0817738
#
# Root relaxation: objective 1.072958e+00, 735 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       1.0729576    1.07296  0.00%     -    0s
#
# Explored 1 nodes (735 simplex iterations) in 0.23 seconds (0.07 work units)
# Thread count was 28 (of 28 available processors)
#
# Solution count 2: 1.07296 1.08177
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.072957646813e+00, best bound 1.072957646813e+00, gap 0.0000%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: 1.0730
#   Energy cost term: 1.0708
#   Heat penalty term: 2.3491
# current hour: 0
# next hour: 1
# 1
# Eigenvalues of the discrete system: [1.83670992e-40 1.49168444e-24 1.83670992e-40 1.49168444e-24]
# The discrete-time system (A_dis) is stable.
# The discrete-time system (A_5min) is stable.
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# m:\RA_project\MSc_stage1_cleaned.py:287: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   times = pd.date_range('2022-01-01', '2022-12-31 23:00', freq='1H', tz=tz)     # Time range
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i7-14700, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 28 logical processors, using up to 28 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 967 rows, 1296 columns and 5500 nonzeros (Min)
# Model fingerprint: 0xec417062
# Model has 144 linear objective coefficients
# Model has 96 quadratic constraints
# Variable types: 1200 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+02]
#   QMatrix range    [1e+03, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 3e+03]
#   RHS range        [1e-01, 4e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 542 rows and 497 columns
# Presolve time: 0.00s
# Presolved: 984 rows, 892 columns, 5446 nonzeros
# Presolved model has 140 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 845 continuous, 47 integer (47 binary)
# Found heuristic solution: objective 1.0566420
#
# Root relaxation: interrupted, 767 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0         1.05664    1.05664  0.00%     -    0s
#
# Explored 1 nodes (767 simplex iterations) in 0.05 seconds (0.07 work units)
# Thread count was 28 (of 28 available processors)
#
# Solution count 1: 1.05664
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.056642025284e+00, best bound 1.056641813448e+00, gap 0.0000%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: 1.0566
#   Energy cost term: 1.0446
#   Heat penalty term: 2.3102
# current hour: 1
# next hour: 2
# 2
# Eigenvalues of the discrete system: [1.83670992e-40 1.49168444e-24 1.83670992e-40 1.49168444e-24]
# The discrete-time system (A_dis) is stable.
# The discrete-time system (A_5min) is stable.
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# m:\RA_project\MSc_stage1_cleaned.py:287: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   times = pd.date_range('2022-01-01', '2022-12-31 23:00', freq='1H', tz=tz)     # Time range
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i7-14700, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 28 logical processors, using up to 28 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 967 rows, 1296 columns and 5500 nonzeros (Min)
# Model fingerprint: 0x5cca3f74
# Model has 144 linear objective coefficients
# Model has 96 quadratic constraints
# Variable types: 1200 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+02]
#   QMatrix range    [1e+03, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 3e+03]
#   RHS range        [2e-05, 4e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 548 rows and 505 columns
# Presolve time: 0.00s
# Presolved: 975 rows, 884 columns, 5422 nonzeros
# Presolved model has 1 quadratic objective terms
# Presolved model has 139 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 838 continuous, 46 integer (46 binary)
# Found heuristic solution: objective 1.0533829
#
# Root relaxation: interrupted, 2672 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0         1.05338    1.05332  0.01%     -    0s
#
# Explored 1 nodes (2672 simplex iterations) in 0.07 seconds (0.08 work units)
# Thread count was 28 (of 28 available processors)
#
# Solution count 1: 1.05338
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.053382932396e+00, best bound 1.053324856375e+00, gap 0.0055%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: 1.0534
#   Energy cost term: 1.0121
#   Heat penalty term: 2.0876
# current hour: 2
# next hour: 3
# 3
# Eigenvalues of the discrete system: [1.83670992e-40 1.49168444e-24 1.83670992e-40 1.49168444e-24]
# The discrete-time system (A_dis) is stable.
# The discrete-time system (A_5min) is stable.
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# m:\RA_project\MSc_stage1_cleaned.py:287: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   times = pd.date_range('2022-01-01', '2022-12-31 23:00', freq='1H', tz=tz)     # Time range
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i7-14700, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 28 logical processors, using up to 28 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 967 rows, 1296 columns and 5500 nonzeros (Min)
# Model fingerprint: 0xf72eb687
# Model has 144 linear objective coefficients
# Model has 96 quadratic constraints
# Variable types: 1200 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+02]
#   QMatrix range    [1e+03, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 3e+03]
#   RHS range        [2e-05, 6e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 550 rows and 507 columns
# Presolve time: 0.00s
# Presolved: 973 rows, 882 columns, 5420 nonzeros
# Presolved model has 1 quadratic objective terms
# Presolved model has 139 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 836 continuous, 46 integer (46 binary)
# Found heuristic solution: objective 1.1916125
#
# Root relaxation: objective 1.188607e+00, 2535 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       1.1886070    1.18861  0.00%     -    0s
#
# Explored 1 nodes (2535 simplex iterations) in 0.10 seconds (0.11 work units)
# Thread count was 28 (of 28 available processors)
#
# Solution count 2: 1.18861 1.19161
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.188606986541e+00, best bound 1.188606986541e+00, gap 0.0000%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: 1.1886
#   Energy cost term: 1.5665
#   Heat penalty term: 6.6303
# current hour: 3
# next hour: 4
# 4
# Eigenvalues of the discrete system: [1.83670992e-40 1.49168444e-24 1.83670992e-40 1.49168444e-24]
# The discrete-time system (A_dis) is stable.
# The discrete-time system (A_5min) is stable.
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# m:\RA_project\MSc_stage1_cleaned.py:287: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   times = pd.date_range('2022-01-01', '2022-12-31 23:00', freq='1H', tz=tz)     # Time range
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i7-14700, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 28 logical processors, using up to 28 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 967 rows, 1296 columns and 5500 nonzeros (Min)
# Model fingerprint: 0x23faf399
# Model has 144 linear objective coefficients
# Model has 96 quadratic constraints
# Variable types: 1200 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+02]
#   QMatrix range    [1e+03, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 3e+03]
#   RHS range        [1e-01, 6e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 554 rows and 512 columns
# Presolve time: 0.01s
# Presolved: 969 rows, 877 columns, 5408 nonzeros
# Presolved model has 1 quadratic objective terms
# Presolved model has 139 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 831 continuous, 46 integer (46 binary)
# Found heuristic solution: objective 1.3006575
#
# Root relaxation: interrupted, 2489 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0         1.30066    1.30055  0.01%     -    0s
#
# Explored 1 nodes (2489 simplex iterations) in 0.07 seconds (0.09 work units)
# Thread count was 28 (of 28 available processors)
#
# Solution count 1: 1.30066
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.300657450763e+00, best bound 1.300548955607e+00, gap 0.0083%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: 1.3007
#   Energy cost term: 1.4497
#   Heat penalty term: 5.1050
# current hour: 4
# next hour: 5
# 5
# Eigenvalues of the discrete system: [1.83670992e-40 1.49168444e-24 1.83670992e-40 1.49168444e-24]
# The discrete-time system (A_dis) is stable.
# The discrete-time system (A_5min) is stable.
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# m:\RA_project\MSc_stage1_cleaned.py:287: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   times = pd.date_range('2022-01-01', '2022-12-31 23:00', freq='1H', tz=tz)     # Time range
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i7-14700, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 28 logical processors, using up to 28 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 967 rows, 1296 columns and 5500 nonzeros (Min)
# Model fingerprint: 0x5fb31b16
# Model has 144 linear objective coefficients
# Model has 96 quadratic constraints
# Variable types: 1200 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+02]
#   QMatrix range    [1e+03, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 3e+03]
#   RHS range        [2e-05, 6e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 559 rows and 517 columns
# Presolve time: 0.01s
# Presolved: 964 rows, 872 columns, 5308 nonzeros
# Presolved model has 1 quadratic objective terms
# Presolved model has 139 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 826 continuous, 46 integer (46 binary)
#
# Root relaxation: objective 1.417243e+00, 2434 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       1.4172434    1.41724  0.00%     -    0s
#
# Explored 1 nodes (2434 simplex iterations) in 0.11 seconds (0.12 work units)
# Thread count was 28 (of 28 available processors)
#
# Solution count 1: 1.41724
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.417243409037e+00, best bound 1.417243409037e+00, gap 0.0000%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: 1.4172
#   Energy cost term: 1.4800
#   Heat penalty term: 5.0907
# current hour: 5
# next hour: 6
# 6
# Eigenvalues of the discrete system: [1.83670992e-40 1.49168444e-24 1.83670992e-40 1.49168444e-24]
# The discrete-time system (A_dis) is stable.
# The discrete-time system (A_5min) is stable.
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# m:\RA_project\MSc_stage1_cleaned.py:287: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   times = pd.date_range('2022-01-01', '2022-12-31 23:00', freq='1H', tz=tz)     # Time range
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i7-14700, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 28 logical processors, using up to 28 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 967 rows, 1296 columns and 5500 nonzeros (Min)
# Model fingerprint: 0xec25d496
# Model has 144 linear objective coefficients
# Model has 96 quadratic constraints
# Variable types: 1200 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+02]
#   QMatrix range    [1e+03, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 3e+03]
#   RHS range        [5e-03, 6e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 559 rows and 529 columns
# Presolve time: 0.01s
# Presolved: 964 rows, 860 columns, 5284 nonzeros
# Presolved model has 1 quadratic objective terms
# Presolved model has 139 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 814 continuous, 46 integer (46 binary)
# Found heuristic solution: objective 1.2068135
#
# Root relaxation: cutoff, 2259 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         1.20681    1.20681  0.00%     -    0s
#
# Explored 1 nodes (2259 simplex iterations) in 0.08 seconds (0.09 work units)
# Thread count was 28 (of 28 available processors)
#
# Solution count 1: 1.20681
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.206813481016e+00, best bound 1.206813481016e+00, gap 0.0000%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: 1.2068
#   Energy cost term: 0.3059
#   Heat penalty term: 0.0240
# current hour: 6
# next hour: 7
# 7
# Eigenvalues of the discrete system: [1.83670992e-40 1.49168444e-24 1.83670992e-40 1.49168444e-24]
# The discrete-time system (A_dis) is stable.
# The discrete-time system (A_5min) is stable.
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# m:\RA_project\MSc_stage1_cleaned.py:287: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   times = pd.date_range('2022-01-01', '2022-12-31 23:00', freq='1H', tz=tz)     # Time range
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i7-14700, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 28 logical processors, using up to 28 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 967 rows, 1296 columns and 5500 nonzeros (Min)
# Model fingerprint: 0x211fdb3b
# Model has 144 linear objective coefficients
# Model has 96 quadratic constraints
# Variable types: 1200 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+02]
#   QMatrix range    [1e+03, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 3e+03]
#   RHS range        [2e-05, 6e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 559 rows and 541 columns
# Presolve time: 0.01s
# Presolved: 964 rows, 848 columns, 5260 nonzeros
# Presolved model has 1 quadratic objective terms
# Presolved model has 139 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 802 continuous, 46 integer (46 binary)
#
# Root relaxation: objective 7.995625e-01, 2000 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.7995625    0.79956  0.00%     -    0s
#
# Explored 1 nodes (2000 simplex iterations) in 0.11 seconds (0.11 work units)
# Thread count was 28 (of 28 available processors)
#
# Solution count 1: 0.799562
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.995624791483e-01, best bound 7.995624791483e-01, gap 0.0000%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: 0.7996
#   Energy cost term: 0.2166
#   Heat penalty term: 0.0202
# current hour: 7
# next hour: 8
# 8
# Eigenvalues of the discrete system: [1.83670992e-40 1.49168444e-24 1.83670992e-40 1.49168444e-24]
# The discrete-time system (A_dis) is stable.
# The discrete-time system (A_5min) is stable.
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# m:\RA_project\MSc_stage1_cleaned.py:287: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   times = pd.date_range('2022-01-01', '2022-12-31 23:00', freq='1H', tz=tz)     # Time range
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i7-14700, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 28 logical processors, using up to 28 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 967 rows, 1296 columns and 5500 nonzeros (Min)
# Model fingerprint: 0x588d8be0
# Model has 144 linear objective coefficients
# Model has 96 quadratic constraints
# Variable types: 1200 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+02]
#   QMatrix range    [1e+03, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 3e+03]
#   RHS range        [5e-03, 6e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 550 rows and 543 columns
# Presolve time: 0.01s
# Presolved: 973 rows, 846 columns, 5348 nonzeros
# Presolved model has 1 quadratic objective terms
# Presolved model has 139 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 800 continuous, 46 integer (46 binary)
# Found heuristic solution: objective 0.4016918
#
# Root relaxation: interrupted, 1780 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0         0.40169    0.40169  0.00%     -    0s
#
# Explored 1 nodes (1780 simplex iterations) in 0.07 seconds (0.08 work units)
# Thread count was 28 (of 28 available processors)
#
# Solution count 1: 0.401692
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.016918240454e-01, best bound 4.016915790373e-01, gap 0.0001%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: 0.4017
#   Energy cost term: 0.1090
#   Heat penalty term: 0.0077
# current hour: 8
# next hour: 9
# 9
# Eigenvalues of the discrete system: [1.83670992e-40 1.49168444e-24 1.83670992e-40 1.49168444e-24]
# The discrete-time system (A_dis) is stable.
# The discrete-time system (A_5min) is stable.
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# m:\RA_project\MSc_stage1_cleaned.py:287: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   times = pd.date_range('2022-01-01', '2022-12-31 23:00', freq='1H', tz=tz)     # Time range
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i7-14700, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 28 logical processors, using up to 28 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 967 rows, 1296 columns and 5500 nonzeros (Min)
# Model fingerprint: 0x77a106fd
# Model has 144 linear objective coefficients
# Model has 96 quadratic constraints
# Variable types: 1200 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+02]
#   QMatrix range    [1e+03, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 3e+03]
#   RHS range        [2e-05, 2e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 275 rows and 227 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 28 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
# Model infeasible -> computing IIS...
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) i7-14700, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 28 logical processors, using up to 28 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
#
# Computing Irreducible Inconsistent Subsystem (IIS)...
#
#            Constraints          |            Bounds           |  Runtime
#       Min       Max     Guess   |   Min       Max     Guess   |
# --------------------------------------------------------------------------
#         0      1063         -         0      1776         -           0s
#         6         6         6         2         2         2           0s
#
# IIS computed: 6 constraints, 2 bounds
# IIS runtime: 0.11 seconds (0.08 work units)
# Warning: variable name "rack 1[0,0]" has a space
# Warning: to let Gurobi read it back, use rlp format
# Infeasible constraint: initial_states_X_1[3]
# Infeasible constraint: initial_inputs_U_0[0]
# Infeasible constraint: initial_inputs_U_0[1]
# Infeasible constraint: avg_TO_0
# Infeasible constraint: heat_balance_0
# Infeasible quadratic constraint: waste_heat_recovery_0
# Infeasible lower bound: rack 1[2,0] >= 0.0
# Infeasible lower bound: H_sub[0] >= 0.0
# Warning: environment still referenced so free is deferred (Continue to use WLS)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 10
#       8     print(mf.CURRENT_HOUR)
#       9     stage2.initialise(mf.CURRENT_HOUR)
# ---> 10     stage2.main()
#      11     stage2.iterate()
#      13 # after 21 hours, it runs into problems of the cut-off
#      14 # validate the 5 mins control action
#      15 # stage2.initialise_plot(10)
#
# File m:\RA_project\MSc_stage2_cleaned.py:494, in main()
#     492         if v.IISUB:
#     493             print(f"Infeasible upper bound: {v.VarName} <= {v.UB}")
# --> 494     raise RuntimeError(f"Optimization stopped with status {m.Status} (INFEASIBLE). See infeasible_stg2.ilp for details.")
#     495 elif m.Status == GRB.UNBOUNDED:
#     496     print("Model is unbounded. Please check your constraints and variable bounds.")
#
# RuntimeError: Optimization stopped with status 3 (INFEASIBLE). See infeasible_stg2.ilp for details.

# %%
mf.CURRENT_HOUR

stage2.plot_results(name="stage2_hourly_results.csv",hours=list(range(0,9)),plots="all")

# %%
# # check initialisation 
# import MSc_stage2_cleaned as stage2
# import Monitored_file as mf

# stage2.initialise(mf.CURRENT_HOUR)

# i = 0; # initialise i 
# for i in range(5): #
#     print(mf.CURRENT_HOUR)
#     stage2.initialise(mf.CURRENT_HOUR)
#     stage2.main() 
#     stage2.iterate()

# # after 21 hours, it runs into problems of the cut-off

# %%
# # validate the 5 mins contorl action 
# # stage2.initialise_plot(10)

# stage2.plot_results(name="stage2_hourly_results.csv",hours=list(range(0,5)),plots="all")

# %%
stage1.A - stage1.A_5min
