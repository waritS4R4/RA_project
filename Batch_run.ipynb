# %%
# To create a day ahead schedule 
import MSc_stage1_cleaned as stage1
stage1.initialise()
# stage1.plot_step_response(stage1.A, stage1.B, stage1.C, stage1.D, stage1.Ts_hour)
# stage1.plot_step_response(stage1.A_5min, stage1.B_5min, stage1.C_5min, stage1.D_5min, stage1.Ts_5min)

stage1.main()
stage1.plot_result()

# %%
# check initialisation 
import MSc_stage2_cleaned as stage2

#stage2.initialise(stage2.mf.CURRENT_HOUR)
i = 0; # initialise i 
for i in range(21): 
    print(stage2.mf.CURRENT_HOUR)
    stage2.initialise(stage2.mf.CURRENT_HOUR) # to import data for each 4 hour period
    stage2.main() 
    stage2.iterate()

# after 21 hours, it runs into problems of the cut-off
# validate the 5 mins control action 
# stage2.initialise_plot(10)
# Out:
# Objective type selected: Multi-objective
# 0
# Eigenvalues of the discrete system: [0.00000000e+00 1.49168444e-24 0.00000000e+00 1.49168444e-24]
# The discrete-time system (A_dis) is stable.
# The discrete-time system (A_5min) is stable.
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# /Users/waritsaralaaiad/Documents/RA/RA_project/MSc_stage1_cleaned.py:288: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   times = pd.date_range('2022-01-01', '2022-12-31 23:00', freq='1H', tz=tz)     # Time range
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 23.2.0 23C71)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 1063 rows, 1344 columns and 5646 nonzeros (Min)
# Model fingerprint: 0xda1423b0
# Model has 144 linear objective coefficients
# Model has 96 quadratic constraints
# Variable types: 1248 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+02]
#   QMatrix range    [1e+03, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 2e+03]
#   RHS range        [5e-02, 4e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 606 rows and 515 columns
# Presolve time: 0.01s
# Presolved: 1016 rows, 922 columns, 5589 nonzeros
# Presolved model has 140 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 875 continuous, 47 integer (47 binary)
#
# Root relaxation: objective 1.032402e+00, 911 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       1.0324018    1.03240  0.00%     -    0s
#
# Explored 1 nodes (911 simplex iterations) in 0.15 seconds (0.13 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1.0324
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.032401810449e+00, best bound 1.032401810449e+00, gap 0.0000%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: 1.0324
#   Energy cost term: 1.0309
#   Heat penalty term: 2.4538
# current hour: 0
# next hour: 1
# 1
# Eigenvalues of the discrete system: [0.00000000e+00 1.49168444e-24 0.00000000e+00 1.49168444e-24]
# The discrete-time system (A_dis) is stable.
# The discrete-time system (A_5min) is stable.
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Set parameter InfUnbdInfo to value 1
# /Users/waritsaralaaiad/Documents/RA/RA_project/MSc_stage1_cleaned.py:288: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   times = pd.date_range('2022-01-01', '2022-12-31 23:00', freq='1H', tz=tz)     # Time range
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 23.2.0 23C71)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 1063 rows, 1344 columns and 5646 nonzeros (Min)
# Model fingerprint: 0x906bee31
# Model has 144 linear objective coefficients
# Model has 96 quadratic constraints
# Variable types: 1248 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+02]
#   QMatrix range    [1e+03, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 2e+03]
#   RHS range        [1e-01, 4e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 606 rows and 515 columns
# Presolve time: 0.01s
# Presolved: 1016 rows, 922 columns, 5589 nonzeros
# Presolved model has 140 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 875 continuous, 47 integer (47 binary)
#
# Root relaxation: objective 1.017357e+00, 793 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       1.0173574    1.01736  0.00%     -    0s
#
# Explored 1 nodes (793 simplex iterations) in 0.19 seconds (0.12 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1.01736
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.017357436246e+00, best bound 1.017357436246e+00, gap 0.0000%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: 1.0174
#   Energy cost term: 1.0062
#   Heat penalty term: 2.4344
# current hour: 1
# next hour: 2
# 2
# Eigenvalues of the discrete system: [0.00000000e+00 1.49168444e-24 0.00000000e+00 1.49168444e-24]
# The discrete-time system (A_dis) is stable.
# The discrete-time system (A_5min) is stable.
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# /Users/waritsaralaaiad/Documents/RA/RA_project/MSc_stage1_cleaned.py:288: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   times = pd.date_range('2022-01-01', '2022-12-31 23:00', freq='1H', tz=tz)     # Time range
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 23.2.0 23C71)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 1063 rows, 1344 columns and 5646 nonzeros (Min)
# Model fingerprint: 0xc24ba4b7
# Model has 144 linear objective coefficients
# Model has 96 quadratic constraints
# Variable types: 1248 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+02]
#   QMatrix range    [1e+03, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 2e+03]
#   RHS range        [1e-01, 4e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 609 rows and 520 columns
# Presolve time: 0.01s
# Presolved: 1010 rows, 917 columns, 5571 nonzeros
# Presolved model has 1 quadratic objective terms
# Presolved model has 139 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 871 continuous, 46 integer (46 binary)
#
# Root relaxation: objective 1.012991e+00, 2955 iterations, 0.03 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       1.0129906    1.01299  0.00%     -    0s
#
# Explored 1 nodes (2955 simplex iterations) in 0.15 seconds (0.13 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1.01299
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.012990648541e+00, best bound 1.012990648541e+00, gap 0.0000%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: 1.0130
#   Energy cost term: 0.9724
#   Heat penalty term: 2.2086
# current hour: 2
# next hour: 3
# 3
# Eigenvalues of the discrete system: [0.00000000e+00 1.49168444e-24 0.00000000e+00 1.49168444e-24]
# The discrete-time system (A_dis) is stable.
# The discrete-time system (A_5min) is stable.
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# /Users/waritsaralaaiad/Documents/RA/RA_project/MSc_stage1_cleaned.py:288: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   times = pd.date_range('2022-01-01', '2022-12-31 23:00', freq='1H', tz=tz)     # Time range
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 23.2.0 23C71)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 1063 rows, 1344 columns and 5646 nonzeros (Min)
# Model fingerprint: 0x881e7606
# Model has 144 linear objective coefficients
# Model has 96 quadratic constraints
# Variable types: 1248 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+02]
#   QMatrix range    [1e+03, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 2e+03]
#   RHS range        [1e-01, 6e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 609 rows and 520 columns
# Presolve time: 0.01s
# Presolved: 1010 rows, 917 columns, 5571 nonzeros
# Presolved model has 1 quadratic objective terms
# Presolved model has 139 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 871 continuous, 46 integer (46 binary)
# Found heuristic solution: objective 1.1880798
#
# Root relaxation: objective 1.142170e+00, 3063 iterations, 0.03 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       1.1421702    1.14217  0.00%     -    0s
#
# Explored 1 nodes (3063 simplex iterations) in 0.15 seconds (0.12 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 1.14217 1.18808
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.142170163887e+00, best bound 1.142170163887e+00, gap 0.0000%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: 1.1422
#   Energy cost term: 1.5207
#   Heat penalty term: 6.8531
# current hour: 3
# next hour: 4
# 4
# Eigenvalues of the discrete system: [0.00000000e+00 1.49168444e-24 0.00000000e+00 1.49168444e-24]
# The discrete-time system (A_dis) is stable.
# The discrete-time system (A_5min) is stable.
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# /Users/waritsaralaaiad/Documents/RA/RA_project/MSc_stage1_cleaned.py:288: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   times = pd.date_range('2022-01-01', '2022-12-31 23:00', freq='1H', tz=tz)     # Time range
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 23.2.0 23C71)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 1063 rows, 1344 columns and 5646 nonzeros (Min)
# Model fingerprint: 0x092896cb
# Model has 144 linear objective coefficients
# Model has 96 quadratic constraints
# Variable types: 1248 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+02]
#   QMatrix range    [1e+03, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 2e+03]
#   RHS range        [1e-01, 6e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 609 rows and 520 columns
# Presolve time: 0.01s
# Presolved: 1010 rows, 917 columns, 5571 nonzeros
# Presolved model has 1 quadratic objective terms
# Presolved model has 139 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 871 continuous, 46 integer (46 binary)
#
# Root relaxation: objective 1.243749e+00, 3149 iterations, 0.04 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       1.2437490    1.24375  0.00%     -    0s
#
# Explored 1 nodes (3149 simplex iterations) in 0.17 seconds (0.14 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1.24375
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.243748976417e+00, best bound 1.243748976417e+00, gap 0.0000%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: 1.2437
#   Energy cost term: 1.3935
#   Heat penalty term: 5.3704
# current hour: 4
# next hour: 5
# 5
# Eigenvalues of the discrete system: [0.00000000e+00 1.49168444e-24 0.00000000e+00 1.49168444e-24]
# The discrete-time system (A_dis) is stable.
# The discrete-time system (A_5min) is stable.
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# /Users/waritsaralaaiad/Documents/RA/RA_project/MSc_stage1_cleaned.py:288: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   times = pd.date_range('2022-01-01', '2022-12-31 23:00', freq='1H', tz=tz)     # Time range
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 23.2.0 23C71)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 1063 rows, 1344 columns and 5646 nonzeros (Min)
# Model fingerprint: 0xf7c79416
# Model has 144 linear objective coefficients
# Model has 96 quadratic constraints
# Variable types: 1248 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+02]
#   QMatrix range    [1e+03, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 2e+03]
#   RHS range        [5e-03, 6e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 609 rows and 520 columns
# Presolve time: 0.01s
# Presolved: 1010 rows, 917 columns, 5571 nonzeros
# Presolved model has 1 quadratic objective terms
# Presolved model has 139 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 871 continuous, 46 integer (46 binary)
#
# Root relaxation: objective 1.345809e+00, 3232 iterations, 0.03 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       1.3458092    1.34581  0.00%     -    0s
#
# Explored 1 nodes (3232 simplex iterations) in 0.15 seconds (0.13 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1.34581
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.345809226221e+00, best bound 1.345809226221e+00, gap 0.0000%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: 1.3458
#   Energy cost term: 1.4097
#   Heat penalty term: 5.4095
# current hour: 5
# next hour: 6
# 6
# Eigenvalues of the discrete system: [0.00000000e+00 1.49168444e-24 0.00000000e+00 1.49168444e-24]
# The discrete-time system (A_dis) is stable.
# The discrete-time system (A_5min) is stable.
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# /Users/waritsaralaaiad/Documents/RA/RA_project/MSc_stage1_cleaned.py:288: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   times = pd.date_range('2022-01-01', '2022-12-31 23:00', freq='1H', tz=tz)     # Time range
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 23.2.0 23C71)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 1063 rows, 1344 columns and 5646 nonzeros (Min)
# Model fingerprint: 0x68e9addd
# Model has 144 linear objective coefficients
# Model has 96 quadratic constraints
# Variable types: 1248 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+02]
#   QMatrix range    [1e+03, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 2e+03]
#   RHS range        [5e-03, 6e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 609 rows and 520 columns
# Presolve time: 0.01s
# Presolved: 1010 rows, 917 columns, 5571 nonzeros
# Presolved model has 1 quadratic objective terms
# Presolved model has 139 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 871 continuous, 46 integer (46 binary)
#
# Root relaxation: objective 1.117753e+00, 2425 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       1.1177528    1.11775  0.00%     -    0s
#
# Explored 1 nodes (2425 simplex iterations) in 0.14 seconds (0.13 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1.11775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.117752792571e+00, best bound 1.117752792571e+00, gap 0.0000%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: 1.1178
#   Energy cost term: 0.2187
#   Heat penalty term: 0.0094
# current hour: 6
# next hour: 7
# 7
# Eigenvalues of the discrete system: [0.00000000e+00 1.49168444e-24 0.00000000e+00 1.49168444e-24]
# The discrete-time system (A_dis) is stable.
# The discrete-time system (A_5min) is stable.
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# /Users/waritsaralaaiad/Documents/RA/RA_project/MSc_stage1_cleaned.py:288: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   times = pd.date_range('2022-01-01', '2022-12-31 23:00', freq='1H', tz=tz)     # Time range
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 23.2.0 23C71)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 1063 rows, 1344 columns and 5646 nonzeros (Min)
# Model fingerprint: 0xef5db9cd
# Model has 144 linear objective coefficients
# Model has 96 quadratic constraints
# Variable types: 1248 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+02]
#   QMatrix range    [1e+03, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 2e+03]
#   RHS range        [5e-03, 6e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 609 rows and 520 columns
# Presolve time: 0.01s
# Presolved: 1010 rows, 917 columns, 5571 nonzeros
# Presolved model has 1 quadratic objective terms
# Presolved model has 139 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 871 continuous, 46 integer (46 binary)
# Found heuristic solution: objective 0.7099345
#
# Root relaxation: interrupted, 2020 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0         0.70993    0.70993  0.00%     -    0s
#
# Explored 1 nodes (2020 simplex iterations) in 0.08 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0.709934
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.099344877947e-01, best bound 7.099341707968e-01, gap 0.0000%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: 0.7099
#   Energy cost term: 0.1300
#   Heat penalty term: 0.0035
# current hour: 7
# next hour: 8
# 8
# Eigenvalues of the discrete system: [0.00000000e+00 1.49168444e-24 0.00000000e+00 1.49168444e-24]
# The discrete-time system (A_dis) is stable.
# The discrete-time system (A_5min) is stable.
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Set parameter InfUnbdInfo to value 1
# /Users/waritsaralaaiad/Documents/RA/RA_project/MSc_stage1_cleaned.py:288: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   times = pd.date_range('2022-01-01', '2022-12-31 23:00', freq='1H', tz=tz)     # Time range
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 23.2.0 23C71)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 1063 rows, 1344 columns and 5646 nonzeros (Min)
# Model fingerprint: 0x106775ce
# Model has 144 linear objective coefficients
# Model has 96 quadratic constraints
# Variable types: 1248 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+02]
#   QMatrix range    [1e+03, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 2e+03]
#   RHS range        [2e-05, 6e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 609 rows and 520 columns
# Presolve time: 0.01s
# Presolved: 1010 rows, 917 columns, 5571 nonzeros
# Presolved model has 1 quadratic objective terms
# Presolved model has 139 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 871 continuous, 46 integer (46 binary)
# Found heuristic solution: objective 0.3194594
#
# Root relaxation: interrupted, 1838 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0         0.31946    0.31946  0.00%     -    0s
#
# Explored 1 nodes (1838 simplex iterations) in 0.08 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0.319459
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.194593822632e-01, best bound 3.194590562974e-01, gap 0.0001%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: 0.3195
#   Energy cost term: 0.0320
#   Heat penalty term: 0.0020
# current hour: 8
# next hour: 9
# 9
# Eigenvalues of the discrete system: [0.00000000e+00 1.49168444e-24 0.00000000e+00 1.49168444e-24]
# The discrete-time system (A_dis) is stable.
# The discrete-time system (A_5min) is stable.
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# /Users/waritsaralaaiad/Documents/RA/RA_project/MSc_stage1_cleaned.py:288: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   times = pd.date_range('2022-01-01', '2022-12-31 23:00', freq='1H', tz=tz)     # Time range
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 23.2.0 23C71)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 1063 rows, 1344 columns and 5646 nonzeros (Min)
# Model fingerprint: 0xcd318526
# Model has 144 linear objective coefficients
# Model has 96 quadratic constraints
# Variable types: 1248 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+02]
#   QMatrix range    [1e+03, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 2e+03]
#   RHS range        [2e-05, 1e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 609 rows and 520 columns
# Presolve time: 0.01s
# Presolved: 1010 rows, 917 columns, 5571 nonzeros
# Presolved model has 1 quadratic objective terms
# Presolved model has 139 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 871 continuous, 46 integer (46 binary)
# Found heuristic solution: objective -0.0384679
#
# Root relaxation: objective -3.852762e-02, 1795 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -0.03853    0    1   -0.03847   -0.03853  0.16%     -    0s
# *    0     0               0      -0.0385276   -0.03853  0.00%     -    0s
#
# Explored 1 nodes (1798 simplex iterations) in 0.09 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: -0.0385276 -0.0384679
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -3.852761723279e-02, best bound -3.852761723279e-02, gap 0.0000%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: -0.0385
#   Energy cost term: -0.0310
#   Heat penalty term: 0.0002
# current hour: 9
# next hour: 10
# 10
# Eigenvalues of the discrete system: [0.00000000e+00 1.49168444e-24 0.00000000e+00 1.49168444e-24]
# The discrete-time system (A_dis) is stable.
# The discrete-time system (A_5min) is stable.
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# /Users/waritsaralaaiad/Documents/RA/RA_project/MSc_stage1_cleaned.py:288: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   times = pd.date_range('2022-01-01', '2022-12-31 23:00', freq='1H', tz=tz)     # Time range
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 23.2.0 23C71)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 1063 rows, 1344 columns and 5646 nonzeros (Min)
# Model fingerprint: 0x1ef13872
# Model has 144 linear objective coefficients
# Model has 96 quadratic constraints
# Variable types: 1248 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+02]
#   QMatrix range    [1e+03, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 2e+03]
#   RHS range        [1e-01, 1e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 609 rows and 518 columns
# Presolve time: 0.01s
# Presolved: 1013 rows, 919 columns, 5581 nonzeros
# Presolved model has 140 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 873 continuous, 46 integer (46 binary)
# Found heuristic solution: objective -0.0529057
#
# Root relaxation: objective -5.368384e-02, 603 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      -0.0536838   -0.05368  0.00%     -    0s
#
# Explored 1 nodes (603 simplex iterations) in 0.09 seconds (0.10 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: -0.0536838 -0.0529057
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.368384016791e-02, best bound -5.368384016791e-02, gap 0.0000%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: -0.0537
#   Energy cost term: -0.0432
#   Heat penalty term: 0.0000
# current hour: 10
# next hour: 11
# 11
# Eigenvalues of the discrete system: [0.00000000e+00 1.49168444e-24 0.00000000e+00 1.49168444e-24]
# The discrete-time system (A_dis) is stable.
# The discrete-time system (A_5min) is stable.
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# /Users/waritsaralaaiad/Documents/RA/RA_project/MSc_stage1_cleaned.py:288: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   times = pd.date_range('2022-01-01', '2022-12-31 23:00', freq='1H', tz=tz)     # Time range
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 23.2.0 23C71)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 1063 rows, 1344 columns and 5646 nonzeros (Min)
# Model fingerprint: 0x61f631cc
# Model has 144 linear objective coefficients
# Model has 96 quadratic constraints
# Variable types: 1248 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+02]
#   QMatrix range    [1e+03, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 2e+03]
#   RHS range        [1e-01, 1e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 606 rows and 515 columns
# Presolve time: 0.01s
# Presolved: 1016 rows, 922 columns, 5589 nonzeros
# Presolved model has 140 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 875 continuous, 47 integer (47 binary)
# Found heuristic solution: objective -0.0067843
#
# Root relaxation: objective -8.472817e-03, 659 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      -0.0084728   -0.00847  0.00%     -    0s
#
# Explored 1 nodes (659 simplex iterations) in 0.08 seconds (0.09 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: -0.00847282 -0.00678428
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -8.472816703139e-03, best bound -8.472816703139e-03, gap 0.0000%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: -0.0085
#   Energy cost term: -0.0071
#   Heat penalty term: 0.0000
# current hour: 11
# next hour: 12
# 12
# Eigenvalues of the discrete system: [0.00000000e+00 1.49168444e-24 0.00000000e+00 1.49168444e-24]
# The discrete-time system (A_dis) is stable.
# The discrete-time system (A_5min) is stable.
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# /Users/waritsaralaaiad/Documents/RA/RA_project/MSc_stage1_cleaned.py:288: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   times = pd.date_range('2022-01-01', '2022-12-31 23:00', freq='1H', tz=tz)     # Time range
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 23.2.0 23C71)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 1063 rows, 1344 columns and 5646 nonzeros (Min)
# Model fingerprint: 0xea82a4f1
# Model has 144 linear objective coefficients
# Model has 96 quadratic constraints
# Variable types: 1248 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+02]
#   QMatrix range    [1e+03, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 2e+03]
#   RHS range        [1e-02, 1e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 596 rows and 505 columns
# Presolve time: 0.01s
# Presolved: 1026 rows, 932 columns, 5609 nonzeros
# Presolved model has 140 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 885 continuous, 47 integer (47 binary)
# Found heuristic solution: objective 0.1370943
#
# Root relaxation: objective 1.368983e-01, 761 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.1368983    0.13690  0.00%     -    0s
#
# Explored 1 nodes (761 simplex iterations) in 0.14 seconds (0.14 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 0.136898 0.137094
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.368982785447e-01, best bound 1.368982785447e-01, gap 0.0000%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: 0.1369
#   Energy cost term: 0.2151
#   Heat penalty term: 0.0382
# current hour: 12
# next hour: 13
# 13
# Eigenvalues of the discrete system: [0.00000000e+00 1.49168444e-24 0.00000000e+00 1.49168444e-24]
# The discrete-time system (A_dis) is stable.
# The discrete-time system (A_5min) is stable.
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# /Users/waritsaralaaiad/Documents/RA/RA_project/MSc_stage1_cleaned.py:288: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   times = pd.date_range('2022-01-01', '2022-12-31 23:00', freq='1H', tz=tz)     # Time range
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 23.2.0 23C71)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 1063 rows, 1344 columns and 5646 nonzeros (Min)
# Model fingerprint: 0xc5d7b7e6
# Model has 144 linear objective coefficients
# Model has 96 quadratic constraints
# Variable types: 1248 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+02]
#   QMatrix range    [1e+03, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 2e+03]
#   RHS range        [1e-02, 1e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 596 rows and 505 columns
# Presolve time: 0.01s
# Presolved: 1026 rows, 932 columns, 5609 nonzeros
# Presolved model has 140 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 885 continuous, 47 integer (47 binary)
#
# Root relaxation: objective 2.079348e-01, 769 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.2079348    0.20793  0.00%     -    0s
#
# Explored 1 nodes (769 simplex iterations) in 0.15 seconds (0.14 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0.207935
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.079348475070e-01, best bound 2.079348475070e-01, gap 0.0000%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: 0.2079
#   Energy cost term: 0.1822
#   Heat penalty term: 0.0044
# current hour: 13
# next hour: 14
# 14
# Eigenvalues of the discrete system: [0.00000000e+00 1.49168444e-24 0.00000000e+00 1.49168444e-24]
# The discrete-time system (A_dis) is stable.
# The discrete-time system (A_5min) is stable.
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# /Users/waritsaralaaiad/Documents/RA/RA_project/MSc_stage1_cleaned.py:288: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   times = pd.date_range('2022-01-01', '2022-12-31 23:00', freq='1H', tz=tz)     # Time range
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 23.2.0 23C71)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 1063 rows, 1344 columns and 5646 nonzeros (Min)
# Model fingerprint: 0xc16d7faa
# Model has 144 linear objective coefficients
# Model has 96 quadratic constraints
# Variable types: 1248 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+02]
#   QMatrix range    [1e+03, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 2e+03]
#   RHS range        [1e-02, 2e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 596 rows and 505 columns
# Presolve time: 0.01s
# Presolved: 1026 rows, 932 columns, 5609 nonzeros
# Presolved model has 140 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 885 continuous, 47 integer (47 binary)
#
# Root relaxation: objective 2.800823e-01, 843 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.2800823    0.28008  0.00%     -    0s
#
# Explored 1 nodes (843 simplex iterations) in 0.14 seconds (0.13 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0.280082
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.800822768903e-01, best bound 2.800822768903e-01, gap 0.0000%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: 0.2801
#   Energy cost term: 0.2530
#   Heat penalty term: 0.0043
# current hour: 14
# next hour: 15
# 15
# Eigenvalues of the discrete system: [0.00000000e+00 1.49168444e-24 0.00000000e+00 1.49168444e-24]
# The discrete-time system (A_dis) is stable.
# The discrete-time system (A_5min) is stable.
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# /Users/waritsaralaaiad/Documents/RA/RA_project/MSc_stage1_cleaned.py:288: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   times = pd.date_range('2022-01-01', '2022-12-31 23:00', freq='1H', tz=tz)     # Time range
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 23.2.0 23C71)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 1063 rows, 1344 columns and 5646 nonzeros (Min)
# Model fingerprint: 0x0c4f7d17
# Model has 144 linear objective coefficients
# Model has 96 quadratic constraints
# Variable types: 1248 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+02]
#   QMatrix range    [1e+03, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 2e+03]
#   RHS range        [1e-02, 5e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 595 rows and 504 columns
# Presolve time: 0.01s
# Presolved: 1027 rows, 933 columns, 5611 nonzeros
# Presolved model has 140 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 886 continuous, 47 integer (47 binary)
#
# Root relaxation: objective 5.951612e-01, 778 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.5951612    0.59516  0.00%     -    0s
#
# Explored 1 nodes (778 simplex iterations) in 0.14 seconds (0.13 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0.595161
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.951612175774e-01, best bound 5.951612175774e-01, gap 0.0000%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: 0.5952
#   Energy cost term: 1.3803
#   Heat penalty term: 4.9494
# current hour: 15
# next hour: 16
# 16
# Eigenvalues of the discrete system: [0.00000000e+00 1.49168444e-24 0.00000000e+00 1.49168444e-24]
# The discrete-time system (A_dis) is stable.
# The discrete-time system (A_5min) is stable.
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# /Users/waritsaralaaiad/Documents/RA/RA_project/MSc_stage1_cleaned.py:288: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   times = pd.date_range('2022-01-01', '2022-12-31 23:00', freq='1H', tz=tz)     # Time range
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 23.2.0 23C71)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 1063 rows, 1344 columns and 5646 nonzeros (Min)
# Model fingerprint: 0x38829b33
# Model has 144 linear objective coefficients
# Model has 96 quadratic constraints
# Variable types: 1248 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+02]
#   QMatrix range    [1e+03, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 2e+03]
#   RHS range        [1e-01, 5e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 601 rows and 512 columns
# Presolve time: 0.01s
# Presolved: 1018 rows, 925 columns, 5587 nonzeros
# Presolved model has 1 quadratic objective terms
# Presolved model has 139 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 879 continuous, 46 integer (46 binary)
# Found heuristic solution: objective 0.8383058
#
# Root relaxation: interrupted, 2898 iterations, 0.02 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0         0.83831    0.83831  0.00%     -    0s
#
# Explored 1 nodes (2898 simplex iterations) in 0.12 seconds (0.11 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0.838306
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.383058122378e-01, best bound 8.383055395114e-01, gap 0.0000%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: 0.8383
#   Energy cost term: 1.3279
#   Heat penalty term: 4.4104
# current hour: 16
# next hour: 17
# 17
# Eigenvalues of the discrete system: [0.00000000e+00 1.49168444e-24 0.00000000e+00 1.49168444e-24]
# The discrete-time system (A_dis) is stable.
# The discrete-time system (A_5min) is stable.
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Set parameter InfUnbdInfo to value 1
# /Users/waritsaralaaiad/Documents/RA/RA_project/MSc_stage1_cleaned.py:288: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   times = pd.date_range('2022-01-01', '2022-12-31 23:00', freq='1H', tz=tz)     # Time range
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 23.2.0 23C71)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 1063 rows, 1344 columns and 5646 nonzeros (Min)
# Model fingerprint: 0x6df2e7ac
# Model has 144 linear objective coefficients
# Model has 96 quadratic constraints
# Variable types: 1248 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+02]
#   QMatrix range    [1e+03, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 2e+03]
#   RHS range        [1e-01, 6e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 599 rows and 510 columns
# Presolve time: 0.01s
# Presolved: 1020 rows, 927 columns, 5591 nonzeros
# Presolved model has 1 quadratic objective terms
# Presolved model has 139 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 881 continuous, 46 integer (46 binary)
# Found heuristic solution: objective 1.0900985
#
# Root relaxation: interrupted, 2714 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0         1.09010    1.09010  0.00%     -    0s
#
# Explored 1 nodes (2714 simplex iterations) in 0.10 seconds (0.10 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1.0901
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.090098482229e+00, best bound 1.090098207412e+00, gap 0.0000%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: 1.0901
#   Energy cost term: 1.3197
#   Heat penalty term: 4.3588
# current hour: 17
# next hour: 18
# 18
# Eigenvalues of the discrete system: [0.00000000e+00 1.49168444e-24 0.00000000e+00 1.49168444e-24]
# The discrete-time system (A_dis) is stable.
# The discrete-time system (A_5min) is stable.
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# /Users/waritsaralaaiad/Documents/RA/RA_project/MSc_stage1_cleaned.py:288: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   times = pd.date_range('2022-01-01', '2022-12-31 23:00', freq='1H', tz=tz)     # Time range
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 23.2.0 23C71)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 1063 rows, 1344 columns and 5646 nonzeros (Min)
# Model fingerprint: 0xdcf796b4
# Model has 144 linear objective coefficients
# Model has 96 quadratic constraints
# Variable types: 1248 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+02]
#   QMatrix range    [1e+03, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 2e+03]
#   RHS range        [1e-01, 6e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 606 rows and 517 columns
# Presolve time: 0.01s
# Presolved: 1013 rows, 920 columns, 5577 nonzeros
# Presolved model has 1 quadratic objective terms
# Presolved model has 139 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 874 continuous, 46 integer (46 binary)
# Found heuristic solution: objective 1.3685523
#
# Root relaxation: interrupted, 3005 iterations, 0.03 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0         1.36855    1.36855  0.00%     -    0s
#
# Explored 1 nodes (3005 simplex iterations) in 0.12 seconds (0.10 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1.36855
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.368552310897e+00, best bound 1.368552041006e+00, gap 0.0000%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: 1.3686
#   Energy cost term: 1.4406
#   Heat penalty term: 5.5254
# current hour: 18
# next hour: 19
# 19
# Eigenvalues of the discrete system: [0.00000000e+00 1.49168444e-24 0.00000000e+00 1.49168444e-24]
# The discrete-time system (A_dis) is stable.
# The discrete-time system (A_5min) is stable.
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# /Users/waritsaralaaiad/Documents/RA/RA_project/MSc_stage1_cleaned.py:288: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   times = pd.date_range('2022-01-01', '2022-12-31 23:00', freq='1H', tz=tz)     # Time range
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 23.2.0 23C71)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 1063 rows, 1344 columns and 5646 nonzeros (Min)
# Model fingerprint: 0x87a4950c
# Model has 144 linear objective coefficients
# Model has 96 quadratic constraints
# Variable types: 1248 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+02]
#   QMatrix range    [1e+03, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 2e+03]
#   RHS range        [2e-05, 6e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 608 rows and 519 columns
# Presolve time: 0.01s
# Presolved: 1011 rows, 918 columns, 5573 nonzeros
# Presolved model has 1 quadratic objective terms
# Presolved model has 139 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 872 continuous, 46 integer (46 binary)
#
# Root relaxation: objective 1.380887e+00, 3286 iterations, 0.03 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       1.3808869    1.38089  0.00%     -    0s
#
# Explored 1 nodes (3286 simplex iterations) in 0.17 seconds (0.14 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1.38089
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.380886912880e+00, best bound 1.380886912880e+00, gap 0.0000%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: 1.3809
#   Energy cost term: 1.4427
#   Heat penalty term: 5.6694
# current hour: 19
# next hour: 20
# 20
# Eigenvalues of the discrete system: [0.00000000e+00 1.49168444e-24 0.00000000e+00 1.49168444e-24]
# The discrete-time system (A_dis) is stable.
# The discrete-time system (A_5min) is stable.
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2712303
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# /Users/waritsaralaaiad/Documents/RA/RA_project/MSc_stage1_cleaned.py:288: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   times = pd.date_range('2022-01-01', '2022-12-31 23:00', freq='1H', tz=tz)     # Time range
# Set parameter InfUnbdInfo to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 23.2.0 23C71)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# InfUnbdInfo  1
#
# Academic license 2712303 - for non-commercial use only - registered to wl___@ed.ac.uk
# Optimize a model with 1063 rows, 1344 columns and 5646 nonzeros (Min)
# Model fingerprint: 0x6b216743
# Model has 144 linear objective coefficients
# Model has 96 quadratic constraints
# Variable types: 1248 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+02]
#   QMatrix range    [1e+03, 6e+03]
#   QLMatrix range   [1e+00, 3e+03]
#   Objective range  [5e-06, 1e-02]
#   Bounds range     [1e-01, 2e+03]
#   RHS range        [1e-01, 6e+03]
#   QRHS range       [5e+02, 5e+02]
# Presolve removed 597 rows and 508 columns
# Presolve time: 0.01s
# Presolved: 1022 rows, 929 columns, 5595 nonzeros
# Presolved model has 1 quadratic objective terms
# Presolved model has 139 bilinear constraint(s)
#
# Solving non-convex MIQCP to global optimality
#
# Variable types: 883 continuous, 46 integer (46 binary)
#
# Root relaxation: objective 1.244278e+00, 2868 iterations, 0.03 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       1.2442782    1.24428  0.00%     -    0s
#
# Explored 1 nodes (2868 simplex iterations) in 0.16 seconds (0.14 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 1.24428
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.244278207724e+00, best bound 1.244278207724e+00, gap 0.0000%
# Warning: environment still referenced so free is deferred (Continue to use WLS)
#
# Optimal objective: 1.2443
#   Energy cost term: 0.7751
#   Heat penalty term: 1.0211
# current hour: 20
# next hour: 21

# %%
stage2.mf.CURRENT_HOUR

stage2.plot_result(name="results/stage2_hourly_results.csv",hours=list(range(0,21)),plots="all")

# %%
# # check initialisation 
# import MSc_stage2_cleaned as stage2
# import Monitored_file as mf

# stage2.initialise(mf.CURRENT_HOUR)

# i = 0; # initialise i 
# for i in range(5): #
#     print(mf.CURRENT_HOUR)
#     stage2.initialise(mf.CURRENT_HOUR)
#     stage2.main() 
#     stage2.iterate()

# # after 21 hours, it runs into problems of the cut-off

# %%
# # validate the 5 mins contorl action 
# # stage2.initialise_plot(10)

# stage2.plot_results(name="stage2_hourly_results.csv",hours=list(range(0,5)),plots="all")
