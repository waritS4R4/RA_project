# %%
# check initialisation 
import MSc_stage2_cleaned as stage2
import Monitored_file as mf

#stage2.initialise(mf.CURRENT_HOUR)

i = 0; # initialise i 
for i in range(5): #
    print(mf.CURRENT_HOUR)
    stage2.initialise(mf.CURRENT_HOUR)
    stage2.main() 
    stage2.iterate()

# after 21 hours, it runs into problems of the cut-off
# validate the 5 mins contorl action 
# stage2.initialise_plot(10)
stage2.plot_results(name="stage2_hourly_results.csv",hours=list(range(0,5)),plots="all")
# Out:
# Data length (number of rows): 180
# INLET_TEMPERATURE shape: (180, 10)
# SERVER_TEMPERATURE shape: (180, 10)
# OUTLET_TEMPERATURE shape: (180, 10)
# RCU_TEMPERATURE shape: (180,)
# SERVER_POWER shape: (180, 10)
# INLET_TEMPERATURE shape: (180, 10)
# Xmeas shape: (30, 180)
# INLET_TEMPERATURE.shape[0] 180
# 0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 10
#       8 for i in range(5): #
#       9     print(mf.CURRENT_HOUR)
# ---> 10     stage2.initialise(mf.CURRENT_HOUR)
#      11     stage2.main()
#      12     stage2.iterate()
#
# File m:\RA_project\MSc_stage2_cleaned.py:28, in initialise(h)
#      25 global optimal_schedule
#      27 # Load the optimal schedule based on the selected mode extracted from the
# ---> 28 if stg1.mode == 0:
#      29     optimal_schedule = pd.read_csv('schedule_single_objective.csv')
#      30 elif stg1.mode == 1:
#
# AttributeError: module 'MSc_stage1_cleaned' has no attribute 'mode'
